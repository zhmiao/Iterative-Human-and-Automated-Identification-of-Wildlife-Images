# %%
from PIL import Image, ImageOps
from torchvision import transforms

# %%
Image.open('/home/zhmiao/datasets/ecology/Mozambique/Mozambique_season_1/Lion/D03_2016_07_01_09_09_05.JPG')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x7F6A7F5D8A50>

# %%
img = Image.open('/home/zhmiao/datasets/ecology/Mozambique/Mozambique_season_1/Lion/D03_2016_07_01_09_09_05.JPG').resize((250, 100))

# %%
img = ImageOps.expand(img, tuple((max(img.size) - e) // 2 for e in list(img.size)))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=250x250 at 0x7F6A3352BA10>

# %%
re = transforms.RandomResizedCrop(224, scale=(0.5, 1.0), ratio=(3.5/4.0, 3.5/3.0))

# %%
hf = transforms.RandomHorizontalFlip()

# %%
re(img)
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7F6A3312DE50>

# %%
import json

# %%
with open('/home/zhmiao/datasets/ecology/CCT_15/eccv_18_annotation_files/cis_test_annotations.json', 'r') as js:
    ann_js = json.load(js)

# %%
ann = ann_js['annotations'][1302]

# %%
ann
# Out:
# {'image_id': '599a59d6-23d2-11e8-a6a3-ec086b02610b',
#  'category_id': 1,
#  'bbox': [814.08, 709.12, 266.2399999999999, 128.0000000000001],
#  'id': '1852'}

# %%
img = Image.open('/home/zhmiao/datasets/ecology/CCT_15/eccv_18_cropped/{}.jpg'.format(ann['image_id']))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2048x1494 at 0x7F6A32857F10>

# %%
img.size
# Out:
# (2048, 1494)

# %%
bbox = ann['bbox']
pil_bbox = (bbox[0], bbox[1], bbox[0]+bbox[2], bbox[1]+bbox[3])
img = img.crop(pil_bbox)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=266x128 at 0x7F6A32849ED0>

# %%
from PIL import ImageOps

# %%
ImageOps.expand(img, tuple((max(img.size) - s) // 2 for s in list(img.size)))
# Out:
# <PIL.Image.Image image mode=RGB size=266x266 at 0x7F6A328BAA10>
